# %%
from ru_accent_poet import accent_line
import ru_accent_poet as accent
import os
import re
import shutil

# %% [markdown]
# ### Iterate over separate files in a folder and write back scanned
#
# Before pushing texts to `ru_accent`, you need to preprocess them a little, since `ru_accent` breaks from random stuff (here is R regexp)
#
# ```t %>% str_remove_all("'") %>%
#     str_replace_all("-", " - ") %>%
#     str_replace_all("/", "")```

# %%
for path, subdirs, files in os.walk("data/prose/prose_samples"):
    for name in files:
        print(os.path.join(path,name))
        accent.write_file([os.path.join(path, name)])
# Out:
# data/prose/prose_samples/prs-500.txt
# data/prose/prose_samples/prs-499.txt
# data/prose/prose_samples/prs-498.txt
# data/prose/prose_samples/prs-497.txt
# data/prose/prose_samples/prs-496.txt
# data/prose/prose_samples/prs-495.txt
# data/prose/prose_samples/prs-494.txt
# data/prose/prose_samples/prs-493.txt
# data/prose/prose_samples/prs-492.txt
# data/prose/prose_samples/prs-491.txt
# data/prose/prose_samples/prs-490.txt
# data/prose/prose_samples/prs-489.txt
# data/prose/prose_samples/prs-488.txt
# data/prose/prose_samples/prs-487.txt
# data/prose/prose_samples/prs-486.txt
# data/prose/prose_samples/prs-485.txt
# data/prose/prose_samples/prs-484.txt
# data/prose/prose_samples/prs-483.txt
# data/prose/prose_samples/prs-482.txt
# data/prose/prose_samples/prs-481.txt
# data/prose/prose_samples/prs-480.txt
# data/prose/prose_samples/prs-479.txt
# data/prose/prose_samples/prs-478.txt
# data/prose/prose_samples/prs-477.txt
# data/prose/prose_samples/prs-476.txt
# ...
